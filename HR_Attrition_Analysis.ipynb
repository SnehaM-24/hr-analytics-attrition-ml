# %% [markdown]
# ## <b> HR Analytics Project- Understanding the Attrition in HR </b>

# %% [markdown]
# - <b>Import libraries</b>

# %%
import pandas as pd # for data wrangling purpose
import numpy as np # Basic computation library
import seaborn as sns # For Visualization
import matplotlib.pyplot as plt # ploting package
# %matplotlib inline
import warnings # Filtering warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# - <b>Load Dataset</b>

# %%
df=pd.read_csv('HR-Employee-Attrition.csv')

# %% [markdown]
# - <b>Basic Data Info (head, info, shape)</b>

# %%
print('No of Rows:',df.shape[0])
print('No of Columns:',df.shape[1])
pd.set_option('display.max_columns', None) # This will enable us to see truncated columns
df.head()

# %%
print('No of Rows:',df.shape[0])
print('No of Columns:',df.shape[1])
pd.set_option('display.max_columns', None) # This will enable us to see truncated columns
df.head()

# %%
df.columns

# %%
df.info()

# %%
# As we have 35 Columns Lets sort Columns by their datatype
df.columns.to_series().groupby(df.dtypes).groups

# %% [markdown]
# #  Statistical Analysis

# %% [markdown]
# ### Data Integrity Check

# %%
df.duplicated().sum()  # This will check the duplicate data for all columns.

# %% [markdown]
# ### Missing value check

# %%
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))

# %% [markdown]
# ### Statistical Matrix

# %%
# Visualizing the statistics of the columns using heatmap.
plt.figure(figsize=(28,10))
sns.heatmap(df.describe(),linewidths = 0.1,fmt='0.1f',annot = True,cmap='PiYG')

# %%
df.describe().T.round(3)

# %%
df['Attrition'].value_counts()

# %%
labels = 'Yes','No',
fig, ax = plt.subplots()
ax.pie(df['Attrition'].value_counts(),labels = labels,radius =2,autopct = '%2.2f%%',explode=[0.1,0.2], shadow=True,)
plt.show()

# %% [markdown]
# #### Start with Enlisting Value counts & Sub-categories of different categorial features available

# %%
Category=['Attrition', 'BusinessTravel', 'Department', 'EducationField',
          'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime' ]
for i in Category:
    print(i)
    print(df[i].value_counts())
    print("="*100)

# %%
sns.set_palette('gist_rainbow_r')
plt.figure(figsize=(20,20), facecolor='white')
plotnumber =1
Category=['Attrition', 'BusinessTravel', 'Department', 'EducationField',
          'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime' ]
for i in Category:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.countplot(df[i])
        plt.xlabel(i,fontsize=20)
        plt.xticks(rotation=30)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Enlisting Value counts & Sub-categories of different Ordinal features available

# %%
Ordinal=['Education','EnvironmentSatisfaction', 'JobInvolvement','JobSatisfaction',
          'RelationshipSatisfaction', 'PerformanceRating', 'WorkLifeBalance' ]
for i in Ordinal:
    print(i)
    print(df[i].value_counts())
    print("="*100)

# %%
sns.set_palette('hsv')
plt.figure(figsize=(20,20), facecolor='white')
plotnumber =1
Ordinal=['Education','EnvironmentSatisfaction', 'JobInvolvement','JobSatisfaction',
          'RelationshipSatisfaction', 'PerformanceRating', 'WorkLifeBalance' ]
for i in Ordinal:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.countplot(df[i])
        plt.xlabel(i,fontsize=20)
        plt.xticks(rotation=30)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Education level of Man power available

# %%
labels='Bachelor','Master','College','Below College','Doctor'
fig, ax = plt.subplots()
ax.pie(df['Education'].value_counts(),labels = labels,radius =2,autopct = '%3.2f%%',explode=[0.1,0.1,0.15,0.2,0.3], shadow=True,)
plt.show()

# %%
df['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
labels ='Research & Development','Sales','Human Resources'
fig,ax= plt.subplots()
ax.pie(df['Department'].value_counts(),labels=labels, radius=2,autopct= '%3.2f%%',explode=[0.1,0.15,0.2],shadow=True)
plt.show()

# %%
pd.crosstab([df.Education],[df.Department], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_a5020_row0_col0 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_a5020_row0_col1 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_a5020_row0_col2 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_a5020_row0_col3 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_a5020_row1_col0, #T_a5020_row1_col2, #T_a5020_row1_col3 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_a5020_row1_col1 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_a5020_row2_col0 {
#   background-color: #99cc66;
#   color: #000000;
# }
# #T_a5020_row2_col1 {
#   background-color: #a0d066;
#   color: #000000;
# }
# #T_a5020_row2_col2 {
#   background-color: #a6d266;
#   color: #000000;
# }
# #T_a5020_row2_col3 {
#   background-color: #a1d066;
#   color: #000000;
# }
# #T_a5020_row3_col0 {
#   background-color: #cce666;
#   color: #000000;
# }
# #T_a5020_row3_col1 {
#   background-color: #c2e066;
#   color: #000000;
# }
# #T_a5020_row3_col2 {
#   background-color: #bcde66;
#   color: #000000;
# }
# #T_a5020_row3_col3 {
#   background-color: #c0e066;
#   color: #000000;
# }
# #T_a5020_row4_col0, #T_a5020_row4_col1, #T_a5020_row4_col2, #T_a5020_row4_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_a5020_row5_col0, #T_a5020_row5_col1, #T_a5020_row5_col2, #T_a5020_row5_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a5020">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th id="T_a5020_level0_col0" class="col_heading level0 col0" >Human Resources</th>
#       <th id="T_a5020_level0_col1" class="col_heading level0 col1" >Research & Development</th>
#       <th id="T_a5020_level0_col2" class="col_heading level0 col2" >Sales</th>
#       <th id="T_a5020_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5020_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a5020_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_a5020_row0_col1" class="data row0 col1" >115</td>
#       <td id="T_a5020_row0_col2" class="data row0 col2" >50</td>
#       <td id="T_a5020_row0_col3" class="data row0 col3" >170</td>
#     </tr>
#     <tr>
#       <th id="T_a5020_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a5020_row1_col0" class="data row1 col0" >13</td>
#       <td id="T_a5020_row1_col1" class="data row1 col1" >182</td>
#       <td id="T_a5020_row1_col2" class="data row1 col2" >87</td>
#       <td id="T_a5020_row1_col3" class="data row1 col3" >282</td>
#     </tr>
#     <tr>
#       <th id="T_a5020_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a5020_row2_col0" class="data row2 col0" >27</td>
#       <td id="T_a5020_row2_col1" class="data row2 col1" >379</td>
#       <td id="T_a5020_row2_col2" class="data row2 col2" >166</td>
#       <td id="T_a5020_row2_col3" class="data row2 col3" >572</td>
#     </tr>
#     <tr>
#       <th id="T_a5020_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_a5020_row3_col0" class="data row3 col0" >15</td>
#       <td id="T_a5020_row3_col1" class="data row3 col1" >255</td>
#       <td id="T_a5020_row3_col2" class="data row3 col2" >128</td>
#       <td id="T_a5020_row3_col3" class="data row3 col3" >398</td>
#     </tr>
#     <tr>
#       <th id="T_a5020_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_a5020_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_a5020_row4_col1" class="data row4 col1" >30</td>
#       <td id="T_a5020_row4_col2" class="data row4 col2" >15</td>
#       <td id="T_a5020_row4_col3" class="data row4 col3" >48</td>
#     </tr>
#     <tr>
#       <th id="T_a5020_level0_row5" class="row_heading level0 row5" >All</th>
#       <td id="T_a5020_row5_col0" class="data row5 col0" >63</td>
#       <td id="T_a5020_row5_col1" class="data row5 col1" >961</td>
#       <td id="T_a5020_row5_col2" class="data row5 col2" >446</td>
#       <td id="T_a5020_row5_col3" class="data row5 col3" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab([df.Education],[df.Department,df.Attrition], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_04342_row0_col0 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# #T_04342_row0_col1, #T_04342_row4_col0, #T_04342_row4_col1, #T_04342_row4_col2, #T_04342_row4_col3, #T_04342_row4_col4, #T_04342_row4_col5, #T_04342_row4_col6 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_04342_row0_col2 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_04342_row0_col3 {
#   background-color: #e0f066;
#   color: #000000;
# }
# #T_04342_row0_col4 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_04342_row0_col5 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_04342_row0_col6 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_04342_row1_col0, #T_04342_row1_col4 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_04342_row1_col1, #T_04342_row3_col1 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_04342_row1_col2, #T_04342_row1_col6 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_04342_row1_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_04342_row1_col5 {
#   background-color: #d0e866;
#   color: #000000;
# }
# #T_04342_row2_col0 {
#   background-color: #92c866;
#   color: #000000;
# }
# #T_04342_row2_col1 {
#   background-color: #badc66;
#   color: #000000;
# }
# #T_04342_row2_col2, #T_04342_row2_col6 {
#   background-color: #a1d066;
#   color: #000000;
# }
# #T_04342_row2_col3 {
#   background-color: #97cb66;
#   color: #000000;
# }
# #T_04342_row2_col4 {
#   background-color: #aad466;
#   color: #000000;
# }
# #T_04342_row2_col5 {
#   background-color: #95ca66;
#   color: #000000;
# }
# #T_04342_row3_col0 {
#   background-color: #cbe566;
#   color: #000000;
# }
# #T_04342_row3_col2 {
#   background-color: #c1e066;
#   color: #000000;
# }
# #T_04342_row3_col3 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_04342_row3_col4 {
#   background-color: #bbdd66;
#   color: #000000;
# }
# #T_04342_row3_col5 {
#   background-color: #c2e066;
#   color: #000000;
# }
# #T_04342_row3_col6 {
#   background-color: #c0e066;
#   color: #000000;
# }
# #T_04342_row5_col0, #T_04342_row5_col1, #T_04342_row5_col2, #T_04342_row5_col3, #T_04342_row5_col4, #T_04342_row5_col5, #T_04342_row5_col6 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_04342">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th id="T_04342_level0_col0" class="col_heading level0 col0" colspan="2">Human Resources</th>
#       <th id="T_04342_level0_col2" class="col_heading level0 col2" colspan="2">Research & Development</th>
#       <th id="T_04342_level0_col4" class="col_heading level0 col4" colspan="2">Sales</th>
#       <th id="T_04342_level0_col6" class="col_heading level0 col6" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Attrition</th>
#       <th id="T_04342_level1_col0" class="col_heading level1 col0" >No</th>
#       <th id="T_04342_level1_col1" class="col_heading level1 col1" >Yes</th>
#       <th id="T_04342_level1_col2" class="col_heading level1 col2" >No</th>
#       <th id="T_04342_level1_col3" class="col_heading level1 col3" >Yes</th>
#       <th id="T_04342_level1_col4" class="col_heading level1 col4" >No</th>
#       <th id="T_04342_level1_col5" class="col_heading level1 col5" >Yes</th>
#       <th id="T_04342_level1_col6" class="col_heading level1 col6" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04342_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_04342_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_04342_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_04342_row0_col2" class="data row0 col2" >96</td>
#       <td id="T_04342_row0_col3" class="data row0 col3" >19</td>
#       <td id="T_04342_row0_col4" class="data row0 col4" >39</td>
#       <td id="T_04342_row0_col5" class="data row0 col5" >11</td>
#       <td id="T_04342_row0_col6" class="data row0 col6" >170</td>
#     </tr>
#     <tr>
#       <th id="T_04342_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_04342_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_04342_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_04342_row1_col2" class="data row1 col2" >159</td>
#       <td id="T_04342_row1_col3" class="data row1 col3" >23</td>
#       <td id="T_04342_row1_col4" class="data row1 col4" >69</td>
#       <td id="T_04342_row1_col5" class="data row1 col5" >18</td>
#       <td id="T_04342_row1_col6" class="data row1 col6" >282</td>
#     </tr>
#     <tr>
#       <th id="T_04342_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_04342_row2_col0" class="data row2 col0" >23</td>
#       <td id="T_04342_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_04342_row2_col2" class="data row2 col2" >323</td>
#       <td id="T_04342_row2_col3" class="data row2 col3" >56</td>
#       <td id="T_04342_row2_col4" class="data row2 col4" >127</td>
#       <td id="T_04342_row2_col5" class="data row2 col5" >39</td>
#       <td id="T_04342_row2_col6" class="data row2 col6" >572</td>
#     </tr>
#     <tr>
#       <th id="T_04342_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_04342_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_04342_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_04342_row3_col2" class="data row3 col2" >223</td>
#       <td id="T_04342_row3_col3" class="data row3 col3" >32</td>
#       <td id="T_04342_row3_col4" class="data row3 col4" >105</td>
#       <td id="T_04342_row3_col5" class="data row3 col5" >23</td>
#       <td id="T_04342_row3_col6" class="data row3 col6" >398</td>
#     </tr>
#     <tr>
#       <th id="T_04342_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_04342_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_04342_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_04342_row4_col2" class="data row4 col2" >27</td>
#       <td id="T_04342_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_04342_row4_col4" class="data row4 col4" >14</td>
#       <td id="T_04342_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_04342_row4_col6" class="data row4 col6" >48</td>
#     </tr>
#     <tr>
#       <th id="T_04342_level0_row5" class="row_heading level0 row5" >All</th>
#       <td id="T_04342_row5_col0" class="data row5 col0" >51</td>
#       <td id="T_04342_row5_col1" class="data row5 col1" >12</td>
#       <td id="T_04342_row5_col2" class="data row5 col2" >828</td>
#       <td id="T_04342_row5_col3" class="data row5 col3" >133</td>
#       <td id="T_04342_row5_col4" class="data row5 col4" >354</td>
#       <td id="T_04342_row5_col5" class="data row5 col5" >92</td>
#       <td id="T_04342_row5_col6" class="data row5 col6" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Employee distribution as per education field and level of education

# %%
df['EducationField'].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
labels ='Life Sciences','Medical','Marketing','Technical Degree','Other','Human Resources'
fig,ax= plt.subplots()
ax.pie(df['EducationField'].value_counts(),labels=labels, radius=2,autopct= '%3.2f%%',explode=[0.1,0.1,0.125,0.15,0.15,0.175],shadow=True)
plt.show()

# %%
 #Let check distribution of education Vs education Field
pd.crosstab([df.Education],[df.EducationField], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_d5425_row0_col0, #T_d5425_row1_col0, #T_d5425_row4_col0, #T_d5425_row4_col1, #T_d5425_row4_col2, #T_d5425_row4_col3, #T_d5425_row4_col4, #T_d5425_row4_col5, #T_d5425_row4_col6 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d5425_row0_col1, #T_d5425_row0_col6 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_d5425_row0_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_d5425_row0_col3 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_d5425_row0_col4 {
#   background-color: #f3f966;
#   color: #000000;
# }
# #T_d5425_row0_col5 {
#   background-color: #e0f066;
#   color: #000000;
# }
# #T_d5425_row1_col1 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_d5425_row1_col2 {
#   background-color: #e7f366;
#   color: #000000;
# }
# #T_d5425_row1_col3 {
#   background-color: #d0e866;
#   color: #000000;
# }
# #T_d5425_row1_col4 {
#   background-color: #c7e366;
#   color: #000000;
# }
# #T_d5425_row1_col5 {
#   background-color: #daec66;
#   color: #000000;
# }
# #T_d5425_row1_col6 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_d5425_row2_col0 {
#   background-color: #70b866;
#   color: #f1f1f1;
# }
# #T_d5425_row2_col1 {
#   background-color: #a2d066;
#   color: #000000;
# }
# #T_d5425_row2_col2 {
#   background-color: #abd566;
#   color: #000000;
# }
# #T_d5425_row2_col3 {
#   background-color: #a0d066;
#   color: #000000;
# }
# #T_d5425_row2_col4, #T_d5425_row3_col2 {
#   background-color: #b7db66;
#   color: #000000;
# }
# #T_d5425_row2_col5 {
#   background-color: #94ca66;
#   color: #000000;
# }
# #T_d5425_row2_col6 {
#   background-color: #a1d066;
#   color: #000000;
# }
# #T_d5425_row3_col0 {
#   background-color: #e1f066;
#   color: #000000;
# }
# #T_d5425_row3_col1 {
#   background-color: #bcde66;
#   color: #000000;
# }
# #T_d5425_row3_col3 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_d5425_row3_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_d5425_row3_col5 {
#   background-color: #c8e366;
#   color: #000000;
# }
# #T_d5425_row3_col6 {
#   background-color: #c0e066;
#   color: #000000;
# }
# #T_d5425_row5_col0, #T_d5425_row5_col1, #T_d5425_row5_col2, #T_d5425_row5_col3, #T_d5425_row5_col4, #T_d5425_row5_col5, #T_d5425_row5_col6 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d5425">
#   <thead>
#     <tr>
#       <th class="index_name level0" >EducationField</th>
#       <th id="T_d5425_level0_col0" class="col_heading level0 col0" >Human Resources</th>
#       <th id="T_d5425_level0_col1" class="col_heading level0 col1" >Life Sciences</th>
#       <th id="T_d5425_level0_col2" class="col_heading level0 col2" >Marketing</th>
#       <th id="T_d5425_level0_col3" class="col_heading level0 col3" >Medical</th>
#       <th id="T_d5425_level0_col4" class="col_heading level0 col4" >Other</th>
#       <th id="T_d5425_level0_col5" class="col_heading level0 col5" >Technical Degree</th>
#       <th id="T_d5425_level0_col6" class="col_heading level0 col6" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5425_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d5425_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_d5425_row0_col1" class="data row0 col1" >67</td>
#       <td id="T_d5425_row0_col2" class="data row0 col2" >14</td>
#       <td id="T_d5425_row0_col3" class="data row0 col3" >63</td>
#       <td id="T_d5425_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_d5425_row0_col5" class="data row0 col5" >19</td>
#       <td id="T_d5425_row0_col6" class="data row0 col6" >170</td>
#     </tr>
#     <tr>
#       <th id="T_d5425_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d5425_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_d5425_row1_col1" class="data row1 col1" >116</td>
#       <td id="T_d5425_row1_col2" class="data row1 col2" >24</td>
#       <td id="T_d5425_row1_col3" class="data row1 col3" >99</td>
#       <td id="T_d5425_row1_col4" class="data row1 col4" >19</td>
#       <td id="T_d5425_row1_col5" class="data row1 col5" >22</td>
#       <td id="T_d5425_row1_col6" class="data row1 col6" >282</td>
#     </tr>
#     <tr>
#       <th id="T_d5425_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d5425_row2_col0" class="data row2 col0" >16</td>
#       <td id="T_d5425_row2_col1" class="data row2 col1" >233</td>
#       <td id="T_d5425_row2_col2" class="data row2 col2" >59</td>
#       <td id="T_d5425_row2_col3" class="data row2 col3" >183</td>
#       <td id="T_d5425_row2_col4" class="data row2 col4" >24</td>
#       <td id="T_d5425_row2_col5" class="data row2 col5" >57</td>
#       <td id="T_d5425_row2_col6" class="data row2 col6" >572</td>
#     </tr>
#     <tr>
#       <th id="T_d5425_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d5425_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_d5425_row3_col1" class="data row3 col1" >173</td>
#       <td id="T_d5425_row3_col2" class="data row3 col2" >52</td>
#       <td id="T_d5425_row3_col3" class="data row3 col3" >104</td>
#       <td id="T_d5425_row3_col4" class="data row3 col4" >33</td>
#       <td id="T_d5425_row3_col5" class="data row3 col5" >31</td>
#       <td id="T_d5425_row3_col6" class="data row3 col6" >398</td>
#     </tr>
#     <tr>
#       <th id="T_d5425_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d5425_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_d5425_row4_col1" class="data row4 col1" >17</td>
#       <td id="T_d5425_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_d5425_row4_col3" class="data row4 col3" >15</td>
#       <td id="T_d5425_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_d5425_row4_col5" class="data row4 col5" >3</td>
#       <td id="T_d5425_row4_col6" class="data row4 col6" >48</td>
#     </tr>
#     <tr>
#       <th id="T_d5425_level0_row5" class="row_heading level0 row5" >All</th>
#       <td id="T_d5425_row5_col0" class="data row5 col0" >27</td>
#       <td id="T_d5425_row5_col1" class="data row5 col1" >606</td>
#       <td id="T_d5425_row5_col2" class="data row5 col2" >159</td>
#       <td id="T_d5425_row5_col3" class="data row5 col3" >464</td>
#       <td id="T_d5425_row5_col4" class="data row5 col4" >82</td>
#       <td id="T_d5425_row5_col5" class="data row5 col5" >132</td>
#       <td id="T_d5425_row5_col6" class="data row5 col6" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Let check distribution of department Vs education Field
pd.crosstab([df.Department],[df.EducationField], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_c75fe_row0_col0, #T_c75fe_row2_col2, #T_c75fe_row3_col0, #T_c75fe_row3_col1, #T_c75fe_row3_col2, #T_c75fe_row3_col3, #T_c75fe_row3_col4, #T_c75fe_row3_col5, #T_c75fe_row3_col6 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_c75fe_row0_col1, #T_c75fe_row0_col2, #T_c75fe_row0_col3, #T_c75fe_row0_col4, #T_c75fe_row0_col5, #T_c75fe_row0_col6, #T_c75fe_row1_col0, #T_c75fe_row1_col2, #T_c75fe_row2_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_c75fe_row1_col1 {
#   background-color: #48a366;
#   color: #f1f1f1;
# }
# #T_c75fe_row1_col3 {
#   background-color: #399c66;
#   color: #f1f1f1;
# }
# #T_c75fe_row1_col4 {
#   background-color: #3a9c66;
#   color: #f1f1f1;
# }
# #T_c75fe_row1_col5 {
#   background-color: #4ba566;
#   color: #f1f1f1;
# }
# #T_c75fe_row1_col6 {
#   background-color: #5cae66;
#   color: #f1f1f1;
# }
# #T_c75fe_row2_col1 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_c75fe_row2_col3 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_c75fe_row2_col4 {
#   background-color: #d9ec66;
#   color: #000000;
# }
# #T_c75fe_row2_col5 {
#   background-color: #c3e166;
#   color: #000000;
# }
# #T_c75fe_row2_col6 {
#   background-color: #badc66;
#   color: #000000;
# }
# </style>
# <table id="T_c75fe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >EducationField</th>
#       <th id="T_c75fe_level0_col0" class="col_heading level0 col0" >Human Resources</th>
#       <th id="T_c75fe_level0_col1" class="col_heading level0 col1" >Life Sciences</th>
#       <th id="T_c75fe_level0_col2" class="col_heading level0 col2" >Marketing</th>
#       <th id="T_c75fe_level0_col3" class="col_heading level0 col3" >Medical</th>
#       <th id="T_c75fe_level0_col4" class="col_heading level0 col4" >Other</th>
#       <th id="T_c75fe_level0_col5" class="col_heading level0 col5" >Technical Degree</th>
#       <th id="T_c75fe_level0_col6" class="col_heading level0 col6" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c75fe_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_c75fe_row0_col0" class="data row0 col0" >27</td>
#       <td id="T_c75fe_row0_col1" class="data row0 col1" >16</td>
#       <td id="T_c75fe_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_c75fe_row0_col3" class="data row0 col3" >13</td>
#       <td id="T_c75fe_row0_col4" class="data row0 col4" >3</td>
#       <td id="T_c75fe_row0_col5" class="data row0 col5" >4</td>
#       <td id="T_c75fe_row0_col6" class="data row0 col6" >63</td>
#     </tr>
#     <tr>
#       <th id="T_c75fe_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_c75fe_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_c75fe_row1_col1" class="data row1 col1" >440</td>
#       <td id="T_c75fe_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_c75fe_row1_col3" class="data row1 col3" >363</td>
#       <td id="T_c75fe_row1_col4" class="data row1 col4" >64</td>
#       <td id="T_c75fe_row1_col5" class="data row1 col5" >94</td>
#       <td id="T_c75fe_row1_col6" class="data row1 col6" >961</td>
#     </tr>
#     <tr>
#       <th id="T_c75fe_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_c75fe_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_c75fe_row2_col1" class="data row2 col1" >150</td>
#       <td id="T_c75fe_row2_col2" class="data row2 col2" >159</td>
#       <td id="T_c75fe_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_c75fe_row2_col4" class="data row2 col4" >15</td>
#       <td id="T_c75fe_row2_col5" class="data row2 col5" >34</td>
#       <td id="T_c75fe_row2_col6" class="data row2 col6" >446</td>
#     </tr>
#     <tr>
#       <th id="T_c75fe_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_c75fe_row3_col0" class="data row3 col0" >27</td>
#       <td id="T_c75fe_row3_col1" class="data row3 col1" >606</td>
#       <td id="T_c75fe_row3_col2" class="data row3 col2" >159</td>
#       <td id="T_c75fe_row3_col3" class="data row3 col3" >464</td>
#       <td id="T_c75fe_row3_col4" class="data row3 col4" >82</td>
#       <td id="T_c75fe_row3_col5" class="data row3 col5" >132</td>
#       <td id="T_c75fe_row3_col6" class="data row3 col6" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Lets work with Job Role

# %%
plt.figure(figsize=(15,7))
sns.countplot(df['JobRole'])
plt.xticks(rotation=45)
plt.show()

# %%
pd.crosstab([df.JobRole],[df.Department], margins=True).style.background_gradient(cmap='gist_rainbow_r')
# Out:
# <style type="text/css">
# #T_a1bb9_row0_col0, #T_a1bb9_row0_col2, #T_a1bb9_row1_col1, #T_a1bb9_row1_col2, #T_a1bb9_row1_col3, #T_a1bb9_row2_col0, #T_a1bb9_row2_col2, #T_a1bb9_row4_col0, #T_a1bb9_row4_col2, #T_a1bb9_row5_col0, #T_a1bb9_row5_col2, #T_a1bb9_row6_col0, #T_a1bb9_row6_col2, #T_a1bb9_row7_col0, #T_a1bb9_row7_col1, #T_a1bb9_row8_col0, #T_a1bb9_row8_col1 {
#   background-color: #ff00bf;
#   color: #f1f1f1;
# }
# #T_a1bb9_row0_col1 {
#   background-color: #8600ff;
#   color: #f1f1f1;
# }
# #T_a1bb9_row0_col3, #T_a1bb9_row3_col1 {
#   background-color: #f300ff;
#   color: #f1f1f1;
# }
# #T_a1bb9_row1_col0 {
#   background-color: #ffc400;
#   color: #000000;
# }
# #T_a1bb9_row2_col1 {
#   background-color: #0033ff;
#   color: #f1f1f1;
# }
# #T_a1bb9_row2_col3 {
#   background-color: #7600ff;
#   color: #f1f1f1;
# }
# #T_a1bb9_row3_col0 {
#   background-color: #5000ff;
#   color: #f1f1f1;
# }
# #T_a1bb9_row3_col2, #T_a1bb9_row5_col1 {
#   background-color: #cd00ff;
#   color: #f1f1f1;
# }
# #T_a1bb9_row3_col3 {
#   background-color: #ff00f0;
#   color: #f1f1f1;
# }
# #T_a1bb9_row4_col1 {
#   background-color: #7000ff;
#   color: #f1f1f1;
# }
# #T_a1bb9_row4_col3 {
#   background-color: #e800ff;
#   color: #f1f1f1;
# }
# #T_a1bb9_row5_col3, #T_a1bb9_row8_col3 {
#   background-color: #ff00da;
#   color: #f1f1f1;
# }
# #T_a1bb9_row6_col1 {
#   background-color: #0064ff;
#   color: #f1f1f1;
# }
# #T_a1bb9_row6_col3 {
#   background-color: #5500ff;
#   color: #f1f1f1;
# }
# #T_a1bb9_row7_col2 {
#   background-color: #b8ff00;
#   color: #000000;
# }
# #T_a1bb9_row7_col3 {
#   background-color: #3400ff;
#   color: #f1f1f1;
# }
# #T_a1bb9_row8_col2 {
#   background-color: #3f00ff;
#   color: #f1f1f1;
# }
# #T_a1bb9_row9_col0, #T_a1bb9_row9_col1, #T_a1bb9_row9_col2, #T_a1bb9_row9_col3 {
#   background-color: #ff0029;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a1bb9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th id="T_a1bb9_level0_col0" class="col_heading level0 col0" >Human Resources</th>
#       <th id="T_a1bb9_level0_col1" class="col_heading level0 col1" >Research & Development</th>
#       <th id="T_a1bb9_level0_col2" class="col_heading level0 col2" >Sales</th>
#       <th id="T_a1bb9_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1bb9_level0_row0" class="row_heading level0 row0" >Healthcare Representative</th>
#       <td id="T_a1bb9_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a1bb9_row0_col1" class="data row0 col1" >131</td>
#       <td id="T_a1bb9_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_a1bb9_row0_col3" class="data row0 col3" >131</td>
#     </tr>
#     <tr>
#       <th id="T_a1bb9_level0_row1" class="row_heading level0 row1" >Human Resources</th>
#       <td id="T_a1bb9_row1_col0" class="data row1 col0" >52</td>
#       <td id="T_a1bb9_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_a1bb9_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_a1bb9_row1_col3" class="data row1 col3" >52</td>
#     </tr>
#     <tr>
#       <th id="T_a1bb9_level0_row2" class="row_heading level0 row2" >Laboratory Technician</th>
#       <td id="T_a1bb9_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_a1bb9_row2_col1" class="data row2 col1" >259</td>
#       <td id="T_a1bb9_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_a1bb9_row2_col3" class="data row2 col3" >259</td>
#     </tr>
#     <tr>
#       <th id="T_a1bb9_level0_row3" class="row_heading level0 row3" >Manager</th>
#       <td id="T_a1bb9_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_a1bb9_row3_col1" class="data row3 col1" >54</td>
#       <td id="T_a1bb9_row3_col2" class="data row3 col2" >37</td>
#       <td id="T_a1bb9_row3_col3" class="data row3 col3" >102</td>
#     </tr>
#     <tr>
#       <th id="T_a1bb9_level0_row4" class="row_heading level0 row4" >Manufacturing Director</th>
#       <td id="T_a1bb9_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_a1bb9_row4_col1" class="data row4 col1" >145</td>
#       <td id="T_a1bb9_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_a1bb9_row4_col3" class="data row4 col3" >145</td>
#     </tr>
#     <tr>
#       <th id="T_a1bb9_level0_row5" class="row_heading level0 row5" >Research Director</th>
#       <td id="T_a1bb9_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_a1bb9_row5_col1" class="data row5 col1" >80</td>
#       <td id="T_a1bb9_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_a1bb9_row5_col3" class="data row5 col3" >80</td>
#     </tr>
#     <tr>
#       <th id="T_a1bb9_level0_row6" class="row_heading level0 row6" >Research Scientist</th>
#       <td id="T_a1bb9_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_a1bb9_row6_col1" class="data row6 col1" >292</td>
#       <td id="T_a1bb9_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_a1bb9_row6_col3" class="data row6 col3" >292</td>
#     </tr>
#     <tr>
#       <th id="T_a1bb9_level0_row7" class="row_heading level0 row7" >Sales Executive</th>
#       <td id="T_a1bb9_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_a1bb9_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_a1bb9_row7_col2" class="data row7 col2" >326</td>
#       <td id="T_a1bb9_row7_col3" class="data row7 col3" >326</td>
#     </tr>
#     <tr>
#       <th id="T_a1bb9_level0_row8" class="row_heading level0 row8" >Sales Representative</th>
#       <td id="T_a1bb9_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_a1bb9_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_a1bb9_row8_col2" class="data row8 col2" >83</td>
#       <td id="T_a1bb9_row8_col3" class="data row8 col3" >83</td>
#     </tr>
#     <tr>
#       <th id="T_a1bb9_level0_row9" class="row_heading level0 row9" >All</th>
#       <td id="T_a1bb9_row9_col0" class="data row9 col0" >63</td>
#       <td id="T_a1bb9_row9_col1" class="data row9 col1" >961</td>
#       <td id="T_a1bb9_row9_col2" class="data row9 col2" >446</td>
#       <td id="T_a1bb9_row9_col3" class="data row9 col3" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12,10))
data=pd.crosstab(df['JobRole'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True,
                    color=['green', 'red'],figsize=(12,8))
plt.title('Attrition as per Job Role', fontsize=20)
plt.xlabel('Job Role',fontsize=15)
plt.show()

# %%
pd.crosstab([df.JobRole,df.Department],[df.Attrition], margins=True).style.background_gradient(cmap='gist_rainbow_r')
# Out:
# <style type="text/css">
# #T_99c52_row0_col0, #T_99c52_row6_col2 {
#   background-color: #c200ff;
#   color: #f1f1f1;
# }
# #T_99c52_row0_col1 {
#   background-color: #ff00f0;
#   color: #f1f1f1;
# }
# #T_99c52_row0_col2 {
#   background-color: #cd00ff;
#   color: #f1f1f1;
# }
# #T_99c52_row1_col0 {
#   background-color: #ff00e0;
#   color: #f1f1f1;
# }
# #T_99c52_row1_col1, #T_99c52_row7_col2, #T_99c52_row10_col2 {
#   background-color: #fe00ff;
#   color: #f1f1f1;
# }
# #T_99c52_row1_col2, #T_99c52_row4_col2 {
#   background-color: #ff00e5;
#   color: #f1f1f1;
# }
# #T_99c52_row2_col0 {
#   background-color: #7000ff;
#   color: #f1f1f1;
# }
# #T_99c52_row2_col1 {
#   background-color: #0028ff;
#   color: #f1f1f1;
# }
# #T_99c52_row2_col2 {
#   background-color: #5500ff;
#   color: #f1f1f1;
# }
# #T_99c52_row3_col0, #T_99c52_row3_col1, #T_99c52_row3_col2 {
#   background-color: #ff00bf;
#   color: #f1f1f1;
# }
# #T_99c52_row4_col0, #T_99c52_row10_col0 {
#   background-color: #ff00eb;
#   color: #f1f1f1;
# }
# #T_99c52_row4_col1 {
#   background-color: #ff00d0;
#   color: #f1f1f1;
# }
# #T_99c52_row5_col0 {
#   background-color: #ff00da;
#   color: #f1f1f1;
# }
# #T_99c52_row5_col1, #T_99c52_row7_col1 {
#   background-color: #ff00ca;
#   color: #f1f1f1;
# }
# #T_99c52_row5_col2 {
#   background-color: #ff00d5;
#   color: #f1f1f1;
# }
# #T_99c52_row6_col0 {
#   background-color: #b700ff;
#   color: #f1f1f1;
# }
# #T_99c52_row6_col1 {
#   background-color: #ff00f6;
#   color: #f1f1f1;
# }
# #T_99c52_row7_col0 {
#   background-color: #f300ff;
#   color: #f1f1f1;
# }
# #T_99c52_row8_col0, #T_99c52_row8_col2 {
#   background-color: #3400ff;
#   color: #f1f1f1;
# }
# #T_99c52_row8_col1 {
#   background-color: #2f00ff;
#   color: #f1f1f1;
# }
# #T_99c52_row9_col0 {
#   background-color: #1900ff;
#   color: #f1f1f1;
# }
# #T_99c52_row9_col1 {
#   background-color: #000dff;
#   color: #f1f1f1;
# }
# #T_99c52_row9_col2 {
#   background-color: #1400ff;
#   color: #f1f1f1;
# }
# #T_99c52_row10_col1 {
#   background-color: #8100ff;
#   color: #f1f1f1;
# }
# #T_99c52_row11_col0, #T_99c52_row11_col1, #T_99c52_row11_col2 {
#   background-color: #ff0029;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_99c52">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_99c52_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_99c52_level0_col1" class="col_heading level0 col1" >Yes</th>
#       <th id="T_99c52_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99c52_level0_row0" class="row_heading level0 row0" >Healthcare Representative</th>
#       <th id="T_99c52_level1_row0" class="row_heading level1 row0" >Research & Development</th>
#       <td id="T_99c52_row0_col0" class="data row0 col0" >122</td>
#       <td id="T_99c52_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_99c52_row0_col2" class="data row0 col2" >131</td>
#     </tr>
#     <tr>
#       <th id="T_99c52_level0_row1" class="row_heading level0 row1" >Human Resources</th>
#       <th id="T_99c52_level1_row1" class="row_heading level1 row1" >Human Resources</th>
#       <td id="T_99c52_row1_col0" class="data row1 col0" >40</td>
#       <td id="T_99c52_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_99c52_row1_col2" class="data row1 col2" >52</td>
#     </tr>
#     <tr>
#       <th id="T_99c52_level0_row2" class="row_heading level0 row2" >Laboratory Technician</th>
#       <th id="T_99c52_level1_row2" class="row_heading level1 row2" >Research & Development</th>
#       <td id="T_99c52_row2_col0" class="data row2 col0" >197</td>
#       <td id="T_99c52_row2_col1" class="data row2 col1" >62</td>
#       <td id="T_99c52_row2_col2" class="data row2 col2" >259</td>
#     </tr>
#     <tr>
#       <th id="T_99c52_level0_row3" class="row_heading level0 row3" rowspan="3">Manager</th>
#       <th id="T_99c52_level1_row3" class="row_heading level1 row3" >Human Resources</th>
#       <td id="T_99c52_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_99c52_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_99c52_row3_col2" class="data row3 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_99c52_level1_row4" class="row_heading level1 row4" >Research & Development</th>
#       <td id="T_99c52_row4_col0" class="data row4 col0" >51</td>
#       <td id="T_99c52_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_99c52_row4_col2" class="data row4 col2" >54</td>
#     </tr>
#     <tr>
#       <th id="T_99c52_level1_row5" class="row_heading level1 row5" >Sales</th>
#       <td id="T_99c52_row5_col0" class="data row5 col0" >35</td>
#       <td id="T_99c52_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_99c52_row5_col2" class="data row5 col2" >37</td>
#     </tr>
#     <tr>
#       <th id="T_99c52_level0_row6" class="row_heading level0 row6" >Manufacturing Director</th>
#       <th id="T_99c52_level1_row6" class="row_heading level1 row6" >Research & Development</th>
#       <td id="T_99c52_row6_col0" class="data row6 col0" >135</td>
#       <td id="T_99c52_row6_col1" class="data row6 col1" >10</td>
#       <td id="T_99c52_row6_col2" class="data row6 col2" >145</td>
#     </tr>
#     <tr>
#       <th id="T_99c52_level0_row7" class="row_heading level0 row7" >Research Director</th>
#       <th id="T_99c52_level1_row7" class="row_heading level1 row7" >Research & Development</th>
#       <td id="T_99c52_row7_col0" class="data row7 col0" >78</td>
#       <td id="T_99c52_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_99c52_row7_col2" class="data row7 col2" >80</td>
#     </tr>
#     <tr>
#       <th id="T_99c52_level0_row8" class="row_heading level0 row8" >Research Scientist</th>
#       <th id="T_99c52_level1_row8" class="row_heading level1 row8" >Research & Development</th>
#       <td id="T_99c52_row8_col0" class="data row8 col0" >245</td>
#       <td id="T_99c52_row8_col1" class="data row8 col1" >47</td>
#       <td id="T_99c52_row8_col2" class="data row8 col2" >292</td>
#     </tr>
#     <tr>
#       <th id="T_99c52_level0_row9" class="row_heading level0 row9" >Sales Executive</th>
#       <th id="T_99c52_level1_row9" class="row_heading level1 row9" >Sales</th>
#       <td id="T_99c52_row9_col0" class="data row9 col0" >269</td>
#       <td id="T_99c52_row9_col1" class="data row9 col1" >57</td>
#       <td id="T_99c52_row9_col2" class="data row9 col2" >326</td>
#     </tr>
#     <tr>
#       <th id="T_99c52_level0_row10" class="row_heading level0 row10" >Sales Representative</th>
#       <th id="T_99c52_level1_row10" class="row_heading level1 row10" >Sales</th>
#       <td id="T_99c52_row10_col0" class="data row10 col0" >50</td>
#       <td id="T_99c52_row10_col1" class="data row10 col1" >33</td>
#       <td id="T_99c52_row10_col2" class="data row10 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_99c52_level0_row11" class="row_heading level0 row11" >All</th>
#       <th id="T_99c52_level1_row11" class="row_heading level1 row11" ></th>
#       <td id="T_99c52_row11_col0" class="data row11 col0" >1233</td>
#       <td id="T_99c52_row11_col1" class="data row11 col1" >237</td>
#       <td id="T_99c52_row11_col2" class="data row11 col2" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Grouping Numeric Features
Numeric=['Age', 'DailyRate', 'DistanceFromHome',
 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction',
 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
 'RelationshipSatisfaction','StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %% [markdown]
# #### Age Vs Attrition

# %%
plt.subplots(figsize=(12,6))
sns.countplot(df['Age'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.set_palette('hsv')
plt.subplots(figsize=(18,8))
sns.countplot(x='Age', hue='Attrition', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=df['TotalWorkingYears'],y=df['MonthlyIncome'])
plt.xlabel('Total Working Years',fontsize=20)
plt.ylabel('Monthly Income',fontsize=20)
plt.title(" Total Working Years vs Monthly Income", fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='Attrition',y='MonthlyIncome',data=df)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='Attrition',y='YearsSinceLastPromotion',data=df)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.show()

# %%
df=pd.read_csv('HR-Employee-Attrition.csv')
print(df)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0                  1                        2  Female          94
# 1                  2                        3    Male          61
# 2                  4                        4    Male          92
# 3                  5                        4  Female          56
# 4                  7                        1    Male          40
# ...              ...                      ...     ...         ...
# 1465            2061                        3    Male          41
# 1466            2062                        4    Male          42
# 1467            2064                        2    Male          87
# 1468            2065                        4    Male          63
# 1469            2068                        2    Male          82
#
#       JobInvolvement  JobLevel                    JobRole  JobSatisfaction  \
# 0                  3         2            Sales Executive                4
# 1                  2         2         Research Scientist                2
# 2                  2         1      Laboratory Technician                3
# 3                  3         1         Research Scientist                3
# 4                  3         1      Laboratory Technician                2
# ...              ...       ...                        ...              ...
# 1465               4         2      Laboratory Technician                4
# 1466               2         3  Healthcare Representative                1
# 1467               4         2     Manufacturing Director                2
# 1468               2         2            Sales Executive                2
# 1469               4         2      Laboratory Technician                3
#
#      MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 0           Single           5993        19479                   8      Y
# 1          Married           5130        24907                   1      Y
# 2           Single           2090         2396                   6      Y
# 3          Married           2909        23159                   1      Y
# 4          Married           3468        16632                   9      Y
# ...            ...            ...          ...                 ...    ...
# 1465       Married           2571        12290                   4      Y
# 1466       Married           9991        21457                   4      Y
# 1467       Married           6142         5174                   1      Y
# 1468       Married           5390        13243                   2      Y
# 1469       Married           4404        10228                   2      Y
#
#      OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0         Yes                 11                  3                         1
# 1          No                 23                  4                         4
# 2         Yes                 15                  3                         2
# 3         Yes                 11                  3                         3
# 4          No                 12                  3                         4
# ...       ...                ...                ...                       ...
# 1465       No                 17                  3                         3
# 1466       No                 15                  3                         1
# 1467      Yes                 20                  4                         2
# 1468       No                 14                  3                         4
# 1469       No                 12                  3                         1
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 0                80                 0                  8
# 1                80                 1                 10
# 2                80                 0                  7
# 3                80                 0                  8
# 4                80                 1                  6
# ...             ...               ...                ...
# 1465             80                 1                 17
# 1466             80                 1                  9
# 1467             80                 1                  6
# 1468             80                 0                 17
# 1469             80                 0                  6
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                         0                1               6
# 1                         3                3              10
# 2                         3                3               0
# 3                         3                3               8
# 4                         3                3               2
# ...                     ...              ...             ...
# 1465                      3                3               5
# 1466                      5                3               7
# 1467                      0                3               6
# 1468                      3                2               9
# 1469                      3                4               4
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                      4                        0                     5
# 1                      7                        1                     7
# 2                      0                        0                     0
# 3                      7                        3                     0
# 4                      2                        2                     2
# ...                  ...                      ...                   ...
# 1465                   2                        0                     3
# 1466                   7                        1                     7
# 1467                   2                        0                     3
# 1468                   6                        0                     8
# 1469                   3                        1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# ### Encoding categorical data

# %%
# Using Label Encoder on target variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Attrition"] = le.fit_transform(df["Attrition"])
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
# Droping unnecessary columns
df.drop(["EmployeeCount", "EmployeeNumber", "Over18", "StandardHours"], axis=1, inplace=True)

# %%
df.shape
# Out:
# (1470, 31)

# %%
# Ordinal Encoding for ordinal variables
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
def ordinal_encode(df, column):
    df[column] = oe.fit_transform(df[column])
    return df

oe_col = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']
df=ordinal_encode(df, oe_col)
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1             2.0       1102         2.0                 1
# 1   49          0             1.0        279         1.0                 8
# 2   37          1             2.0       1373         1.0                 2
# 3   33          0             1.0       1392         1.0                 3
# 4   27          0             2.0        591         1.0                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0          2             1.0                        2     0.0          94
# 1          1             1.0                        3     1.0          61
# 2          2             4.0                        4     1.0          92
# 3          4             1.0                        4     0.0          56
# 4          1             3.0                        1     1.0          40
#
#    JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# 0               3         2      7.0                4            2.0
# 1               2         2      6.0                2            1.0
# 2               2         1      2.0                3            2.0
# 3               3         1      6.0                3            1.0
# 4               3         1      2.0                2            1.0
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# 0           5993        19479                   8       1.0
# 1           5130        24907                   1       0.0
# 2           2090         2396                   6       1.0
# 3           2909        23159                   1       1.0
# 4           3468        16632                   9       0.0
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0                 11                  3                         1
# 1                 23                  4                         4
# 2                 15                  3                         2
# 3                 11                  3                         3
# 4                 12                  3                         4
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %% [markdown]
# ### Outliers Detection and Removal

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in Numeric:
    if plotnumber<=28:
        ax=plt.subplot(7,4,plotnumber)
        sns.boxplot(df[column],color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# #### Features containing outliers

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy() # reassigning the changed dataframe name to our original dataframe name
# Out:
# Shape of the dataframe before removing outliers:  (1470, 31)
# Shape of the dataframe after removing outliers:  (1387, 31)
# Percentage of data loss post outlier removal:  5.646258503401361

# %% [markdown]
# ##### Data Loss

# %%
print("\033[1m"+'Percentage Data Loss :'+"\033[0m",((1470-1387)/1470)*100,'%')
# Out:
# Percentage Data Loss : 5.646258503401361 %

# %% [markdown]
# ### Feature selection and Engineering
# ### 1. Skewness of features

# %%
df.skew()
# Out:
# Age                         0.472280
# Attrition                   1.805983
# BusinessTravel             -1.426774
# DailyRate                  -0.017078
# Department                  0.183919
# DistanceFromHome            0.954752
# Education                  -0.289024
# EducationField              0.544868
# EnvironmentSatisfaction    -0.325285
# Gender                     -0.417296
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    1.126075
# JobRole                    -0.386843
# JobSatisfaction            -0.345612
# MaritalStatus              -0.160952
# MonthlyIncome               1.544770
# MonthlyRate                 0.030596
# NumCompaniesWorked          1.037715
# OverTime                    0.954751
# PercentSalaryHike           0.800592
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.962332
# TotalWorkingYears           1.034487
# TrainingTimesLastYear       0.577614
# WorkLifeBalance            -0.557100
# YearsAtCompany              1.248623
# YearsInCurrentRole          0.726675
# YearsSinceLastPromotion     1.756335
# YearsWithCurrManager        0.694506
# dtype: float64

# %%
# Splitting data in target and dependent feature
X = df.drop(['Attrition'], axis =1)
Y = df['Attrition']

# %% [markdown]
# #### Transforming  skew data using power transform

# %%
from sklearn.preprocessing import power_transform
x = df
df = power_transform(x)
df = pd.DataFrame(df, columns=x.columns)
df.skew()
# Out:
# Age                        -0.004079
# Attrition                   1.805983
# BusinessTravel             -0.960583
# DailyRate                  -0.199742
# Department                  0.015095
# DistanceFromHome           -0.008149
# Education                  -0.103747
# EducationField             -0.008642
# EnvironmentSatisfaction    -0.205472
# Gender                     -0.417296
# HourlyRate                 -0.105678
# JobInvolvement             -0.018801
# JobLevel                    0.110769
# JobRole                    -0.337641
# JobSatisfaction            -0.217730
# MaritalStatus              -0.158253
# MonthlyIncome               0.027700
# MonthlyRate                -0.176560
# NumCompaniesWorked          0.016175
# OverTime                    0.954751
# PercentSalaryHike           0.112128
# PerformanceRating           0.000000
# RelationshipSatisfaction   -0.191406
# StockOptionLevel            0.089929
# TotalWorkingYears          -0.009666
# TrainingTimesLastYear       0.057949
# WorkLifeBalance            -0.011133
# YearsAtCompany             -0.025230
# YearsInCurrentRole         -0.069631
# YearsSinceLastPromotion     0.212301
# YearsWithCurrManager       -0.070570
# dtype: float64

# %% [markdown]
# ### 2. Corrleation

# %%
df.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159366        0.022340   0.021946
# Attrition                -0.159366   1.000000       -0.001041  -0.057220
# BusinessTravel            0.022340  -0.001041        1.000000  -0.004606
# DailyRate                 0.021946  -0.057220       -0.004606   1.000000
# Department               -0.038242   0.063637       -0.003521  -0.005398
# DistanceFromHome         -0.011265   0.081788       -0.032873  -0.008171
# Education                 0.198502  -0.032703       -0.010560  -0.018442
# EducationField           -0.032676   0.023585        0.022576   0.040645
# EnvironmentSatisfaction   0.014098  -0.112393        0.001183   0.033123
# Gender                   -0.039430   0.036252       -0.025364  -0.005242
# HourlyRate                0.025465  -0.001532        0.025424   0.014279
# JobInvolvement            0.036424  -0.133957        0.028261   0.048004
# JobLevel                  0.453902  -0.171968        0.018996   0.022978
# JobRole                  -0.112957   0.064283        0.000213  -0.015437
# JobSatisfaction           0.011763  -0.114206       -0.032491   0.042698
# MaritalStatus            -0.104372   0.160960        0.018687  -0.074113
# MonthlyIncome             0.443747  -0.161848        0.033746   0.035004
# MonthlyRate               0.026954   0.014888       -0.010307  -0.029844
# NumCompaniesWorked        0.309209   0.050314        0.018764   0.032948
# OverTime                  0.034180   0.257237        0.022378   0.020294
# PercentSalaryHike         0.005891  -0.006267       -0.023004   0.027802
# PerformanceRating        -0.000617   0.010781       -0.018274   0.000574
# RelationshipSatisfaction  0.041744  -0.052344       -0.029660   0.004516
# StockOptionLevel          0.054506  -0.136676       -0.015159   0.048361
# TotalWorkingYears         0.636136  -0.185619        0.029818   0.046173
# TrainingTimesLastYear    -0.019008  -0.057285        0.010322   0.005861
# WorkLifeBalance          -0.016913  -0.062492       -0.014140  -0.044266
# YearsAtCompany            0.177620  -0.166455       -0.027164  -0.003580
# YearsInCurrentRole        0.121508  -0.171015       -0.029257   0.022899
# YearsSinceLastPromotion   0.103632  -0.029263       -0.027283  -0.043870
# YearsWithCurrManager      0.121747  -0.162297       -0.044321  -0.011516
#
#                           Department  DistanceFromHome  Education  \
# Age                        -0.038242         -0.011265   0.198502
# Attrition                   0.063637          0.081788  -0.032703
# BusinessTravel             -0.003521         -0.032873  -0.010560
# DailyRate                  -0.005398         -0.008171  -0.018442
# Department                  1.000000          0.023919   0.012846
# DistanceFromHome            0.023919          1.000000   0.001084
# Education                   0.012846          0.001084   1.000000
# EducationField              0.013432          0.005882  -0.038017
# EnvironmentSatisfaction    -0.014540         -0.019279  -0.026223
# Gender                     -0.030618         -0.000819  -0.019166
# HourlyRate                 -0.002412          0.028230   0.010848
# JobInvolvement             -0.024040          0.010106   0.041343
# JobLevel                    0.126809          0.008498   0.083065
# JobRole                     0.678627         -0.000537   0.015140
# JobSatisfaction             0.029521         -0.009284  -0.007219
# MaritalStatus               0.052086         -0.021816  -0.012726
# MonthlyIncome               0.071876         -0.015040   0.072670
# MonthlyRate                 0.022741          0.037052  -0.018540
# NumCompaniesWorked         -0.044344         -0.028307   0.130812
# OverTime                    0.014908          0.026520  -0.017166
# PercentSalaryHike          -0.022678          0.035864  -0.011344
# PerformanceRating          -0.039364          0.023678  -0.023487
# RelationshipSatisfaction   -0.037705          0.007885  -0.002393
# StockOptionLevel           -0.003424          0.049976   0.028494
# TotalWorkingYears          -0.016246         -0.001092   0.125613
# TrainingTimesLastYear       0.036092         -0.034386  -0.026879
# WorkLifeBalance             0.026978         -0.034398   0.007844
# YearsAtCompany              0.032583          0.011579   0.033313
# YearsInCurrentRole          0.065536          0.019039   0.058007
# YearsSinceLastPromotion     0.048931          0.006635   0.042517
# YearsWithCurrManager        0.034216         -0.000221   0.031210
#
#                           EducationField  EnvironmentSatisfaction    Gender  \
# Age                            -0.032676                 0.014098 -0.039430
# Attrition                       0.023585                -0.112393  0.036252
# BusinessTravel                  0.022576                 0.001183 -0.025364
# DailyRate                       0.040645                 0.033123 -0.005242
# Department                      0.013432                -0.014540 -0.030618
# DistanceFromHome                0.005882                -0.019279 -0.000819
# Education                      -0.038017                -0.026223 -0.019166
# EducationField                  1.000000                 0.047924  0.010676
# EnvironmentSatisfaction         0.047924                 1.000000 -0.015715
# Gender                          0.010676                -0.015715  1.000000
# HourlyRate                     -0.006539                -0.040459  0.004768
# JobInvolvement                 -0.006876                -0.012720  0.011939
# JobLevel                       -0.035795                 0.013835 -0.056970
# JobRole                         0.017492                -0.022354 -0.036831
# JobSatisfaction                -0.050934                -0.011186  0.036302
# MaritalStatus                   0.012073                -0.012453 -0.056786
# MonthlyIncome                  -0.030017                 0.003011 -0.047362
# MonthlyRate                    -0.023384                 0.032916 -0.045850
# NumCompaniesWorked              0.001983                 0.015298 -0.030920
# OverTime                        0.007912                 0.059355 -0.051558
# PercentSalaryHike              -0.007845                -0.026797  0.005443
# PerformanceRating              -0.003621                -0.025299 -0.010757
# RelationshipSatisfaction       -0.013734                 0.018414  0.041458
# StockOptionLevel               -0.015355                 0.013330  0.026438
# TotalWorkingYears              -0.012375                -0.001669 -0.058555
# TrainingTimesLastYear           0.050502                -0.019318 -0.040211
# WorkLifeBalance                 0.034038                 0.032492  0.000134
# YearsAtCompany                 -0.012950                 0.006621 -0.045123
# YearsInCurrentRole             -0.010614                 0.038837 -0.025536
# YearsSinceLastPromotion         0.034094                 0.027943 -0.028162
# YearsWithCurrManager            0.013437                 0.001606 -0.036280
#
#                           HourlyRate  JobInvolvement  JobLevel   JobRole  \
# Age                         0.025465        0.036424  0.453902 -0.112957
# Attrition                  -0.001532       -0.133957 -0.171968  0.064283
# BusinessTravel              0.025424        0.028261  0.018996  0.000213
# DailyRate                   0.014279        0.048004  0.022978 -0.015437
# Department                 -0.002412       -0.024040  0.126809  0.678627
# DistanceFromHome            0.028230        0.010106  0.008498 -0.000537
# Education                   0.010848        0.041343  0.083065  0.015140
# EducationField             -0.006539       -0.006876 -0.035795  0.017492
# EnvironmentSatisfaction    -0.040459       -0.012720  0.013835 -0.022354
# Gender                      0.004768        0.011939 -0.056970 -0.036831
# HourlyRate                  1.000000        0.049577 -0.034507 -0.024404
# JobInvolvement              0.049577        1.000000 -0.005280  0.007655
# JobLevel                   -0.034507       -0.005280  1.000000 -0.067968
# JobRole                    -0.024404        0.007655 -0.067968  1.000000
# JobSatisfaction            -0.069016        0.003910  0.014973  0.015361
# MaritalStatus              -0.007768       -0.044455 -0.067931  0.063149
# MonthlyIncome              -0.024587       -0.010269  0.940948 -0.077012
# MonthlyRate                -0.011663       -0.005142  0.043085  0.002271
# NumCompaniesWorked          0.019187        0.011934  0.155141 -0.067264
# OverTime                   -0.004304        0.000837  0.005305  0.043027
# PercentSalaryHike          -0.015490       -0.016065 -0.029366  0.001921
# PerformanceRating          -0.006088       -0.026693 -0.021065 -0.020509
# RelationshipSatisfaction    0.005532        0.037020  0.014398 -0.024408
# StockOptionLevel            0.041972        0.023160  0.018698 -0.015274
# TotalWorkingYears          -0.009929        0.001788  0.752489 -0.132158
# TrainingTimesLastYear      -0.014778       -0.009103 -0.019223  0.002137
# WorkLifeBalance            -0.010359       -0.006875  0.044859  0.019427
# YearsAtCompany             -0.026974        0.003191  0.418382 -0.043248
# YearsInCurrentRole         -0.032875        0.012514  0.297038 -0.003287
# YearsSinceLastPromotion    -0.050165       -0.014229  0.216612 -0.002902
# YearsWithCurrManager       -0.018562        0.029998  0.302023 -0.017225
#
#                           JobSatisfaction  MaritalStatus  MonthlyIncome  \
# Age                              0.011763      -0.104372       0.443747
# Attrition                       -0.114206       0.160960      -0.161848
# BusinessTravel                  -0.032491       0.018687       0.033746
# DailyRate                        0.042698      -0.074113       0.035004
# Department                       0.029521       0.052086       0.071876
# DistanceFromHome                -0.009284      -0.021816      -0.015040
# Education                       -0.007219      -0.012726       0.072670
# EducationField                  -0.050934       0.012073      -0.030017
# EnvironmentSatisfaction         -0.011186      -0.012453       0.003011
# Gender                           0.036302      -0.056786      -0.047362
# HourlyRate                      -0.069016      -0.007768      -0.024587
# JobInvolvement                   0.003910      -0.044455      -0.010269
# JobLevel                         0.014973      -0.067931       0.940948
# JobRole                          0.015361       0.063149      -0.077012
# JobSatisfaction                  1.000000       0.022490       0.011954
# MaritalStatus                    0.022490       1.000000      -0.064885
# MonthlyIncome                    0.011954      -0.064885       1.000000
# MonthlyRate                     -0.007395       0.029546       0.042510
# NumCompaniesWorked              -0.049796      -0.041353       0.168618
# OverTime                         0.025022      -0.014745       0.014046
# PercentSalaryHike                0.017402       0.012709      -0.022710
# PerformanceRating                0.003409       0.005893      -0.016518
# RelationshipSatisfaction        -0.010531       0.023225       0.022203
# StockOptionLevel                 0.008988      -0.663052       0.008439
# TotalWorkingYears                0.002978      -0.086909       0.741363
# TrainingTimesLastYear           -0.011365       0.016893      -0.025888
# WorkLifeBalance                 -0.024311       0.018141       0.032167
# YearsAtCompany                   0.029345      -0.046321       0.380543
# YearsInCurrentRole               0.021082      -0.056760       0.260340
# YearsSinceLastPromotion          0.019533      -0.013044       0.196282
# YearsWithCurrManager             0.002675      -0.043572       0.259423
#
#                           MonthlyRate  NumCompaniesWorked  OverTime  \
# Age                          0.026954            0.309209  0.034180
# Attrition                    0.014888            0.050314  0.257237
# BusinessTravel              -0.010307            0.018764  0.022378
# DailyRate                   -0.029844            0.032948  0.020294
# Department                   0.022741           -0.044344  0.014908
# DistanceFromHome             0.037052           -0.028307  0.026520
# Education                   -0.018540            0.130812 -0.017166
# EducationField              -0.023384            0.001983  0.007912
# EnvironmentSatisfaction      0.032916            0.015298  0.059355
# Gender                      -0.045850           -0.030920 -0.051558
# HourlyRate                  -0.011663            0.019187 -0.004304
# JobInvolvement              -0.005142            0.011934  0.000837
# JobLevel                     0.043085            0.155141  0.005305
# JobRole                      0.002271           -0.067264  0.043027
# JobSatisfaction             -0.007395           -0.049796  0.025022
# MaritalStatus                0.029546           -0.041353 -0.014745
# MonthlyIncome                0.042510            0.168618  0.014046
# MonthlyRate                  1.000000            0.016440  0.005552
# NumCompaniesWorked           0.016440            1.000000 -0.020059
# OverTime                     0.005552           -0.020059  1.000000
# PercentSalaryHike           -0.013630           -0.005976 -0.000886
# PerformanceRating           -0.020675           -0.011690  0.011654
# RelationshipSatisfaction    -0.005290            0.048606  0.048832
# StockOptionLevel            -0.038998            0.035681 -0.000756
# TotalWorkingYears            0.017482            0.273155  0.017335
# TrainingTimesLastYear        0.024648           -0.068857 -0.081081
# WorkLifeBalance              0.002295            0.000979 -0.032425
# YearsAtCompany              -0.033970           -0.141535 -0.019568
# YearsInCurrentRole          -0.008861           -0.115930 -0.021968
# YearsSinceLastPromotion     -0.010779           -0.064930 -0.004751
# YearsWithCurrManager        -0.033466           -0.128915 -0.031931
#
#                           PercentSalaryHike  PerformanceRating  \
# Age                                0.005891          -0.000617
# Attrition                         -0.006267           0.010781
# BusinessTravel                    -0.023004          -0.018274
# DailyRate                          0.027802           0.000574
# Department                        -0.022678          -0.039364
# DistanceFromHome                   0.035864           0.023678
# Education                         -0.011344          -0.023487
# EducationField                    -0.007845          -0.003621
# EnvironmentSatisfaction           -0.026797          -0.025299
# Gender                             0.005443          -0.010757
# HourlyRate                        -0.015490          -0.006088
# JobInvolvement                    -0.016065          -0.026693
# JobLevel                          -0.029366          -0.021065
# JobRole                            0.001921          -0.020509
# JobSatisfaction                    0.017402           0.003409
# MaritalStatus                      0.012709           0.005893
# MonthlyIncome                     -0.022710          -0.016518
# MonthlyRate                       -0.013630          -0.020675
# NumCompaniesWorked                -0.005976          -0.011690
# OverTime                          -0.000886           0.011654
# PercentSalaryHike                  1.000000           0.768868
# PerformanceRating                  0.768868           1.000000
# RelationshipSatisfaction          -0.037246          -0.028131
# StockOptionLevel                   0.004454           0.002938
# TotalWorkingYears                 -0.019235           0.003876
# TrainingTimesLastYear             -0.008951          -0.016177
# WorkLifeBalance                   -0.011006           0.003659
# YearsAtCompany                    -0.030377           0.008069
# YearsInCurrentRole                -0.011269           0.021699
# YearsSinceLastPromotion           -0.034832           0.006845
# YearsWithCurrManager              -0.011293           0.019275
#
#                           RelationshipSatisfaction  StockOptionLevel  \
# Age                                       0.041744          0.054506
# Attrition                                -0.052344         -0.136676
# BusinessTravel                           -0.029660         -0.015159
# DailyRate                                 0.004516          0.048361
# Department                               -0.037705         -0.003424
# DistanceFromHome                          0.007885          0.049976
# Education                                -0.002393          0.028494
# EducationField                           -0.013734         -0.015355
# EnvironmentSatisfaction                   0.018414          0.013330
# Gender                                    0.041458          0.026438
# HourlyRate                                0.005532          0.041972
# JobInvolvement                            0.037020          0.023160
# JobLevel                                  0.014398          0.018698
# JobRole                                  -0.024408         -0.015274
# JobSatisfaction                          -0.010531          0.008988
# MaritalStatus                             0.023225         -0.663052
# MonthlyIncome                             0.022203          0.008439
# MonthlyRate                              -0.005290         -0.038998
# NumCompaniesWorked                        0.048606          0.035681
# OverTime                                  0.048832         -0.000756
# PercentSalaryHike                        -0.037246          0.004454
# PerformanceRating                        -0.028131          0.002938
# RelationshipSatisfaction                  1.000000         -0.046612
# StockOptionLevel                         -0.046612          1.000000
# TotalWorkingYears                         0.006388          0.027590
# TrainingTimesLastYear                     0.001240          0.016626
# WorkLifeBalance                           0.023191          0.003430
# YearsAtCompany                           -0.014690          0.033043
# YearsInCurrentRole                       -0.030128          0.060600
# YearsSinceLastPromotion                  -0.011251          0.022084
# YearsWithCurrManager                     -0.014141          0.048192
#
#                           TotalWorkingYears  TrainingTimesLastYear  \
# Age                                0.636136              -0.019008
# Attrition                         -0.185619              -0.057285
# BusinessTravel                     0.029818               0.010322
# DailyRate                          0.046173               0.005861
# Department                        -0.016246               0.036092
# DistanceFromHome                  -0.001092              -0.034386
# Education                          0.125613              -0.026879
# EducationField                    -0.012375               0.050502
# EnvironmentSatisfaction           -0.001669              -0.019318
# Gender                            -0.058555              -0.040211
# HourlyRate                        -0.009929              -0.014778
# JobInvolvement                     0.001788              -0.009103
# JobLevel                           0.752489              -0.019223
# JobRole                           -0.132158               0.002137
# JobSatisfaction                    0.002978              -0.011365
# MaritalStatus                     -0.086909               0.016893
# MonthlyIncome                      0.741363              -0.025888
# MonthlyRate                        0.017482               0.024648
# NumCompaniesWorked                 0.273155              -0.068857
# OverTime                           0.017335              -0.081081
# PercentSalaryHike                 -0.019235              -0.008951
# PerformanceRating                  0.003876              -0.016177
# RelationshipSatisfaction           0.006388               0.001240
# StockOptionLevel                   0.027590               0.016626
# TotalWorkingYears                  1.000000              -0.033750
# TrainingTimesLastYear             -0.033750               1.000000
# WorkLifeBalance                    0.011362               0.032070
# YearsAtCompany                     0.490539               0.001604
# YearsInCurrentRole                 0.367255               0.002912
# YearsSinceLastPromotion            0.249712               0.021902
# YearsWithCurrManager               0.378519               0.001316
#
#                           WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Age                             -0.016913        0.177620            0.121508
# Attrition                       -0.062492       -0.166455           -0.171015
# BusinessTravel                  -0.014140       -0.027164           -0.029257
# DailyRate                       -0.044266       -0.003580            0.022899
# Department                       0.026978        0.032583            0.065536
# DistanceFromHome                -0.034398        0.011579            0.019039
# Education                        0.007844        0.033313            0.058007
# EducationField                   0.034038       -0.012950           -0.010614
# EnvironmentSatisfaction          0.032492        0.006621            0.038837
# Gender                           0.000134       -0.045123           -0.025536
# HourlyRate                      -0.010359       -0.026974           -0.032875
# JobInvolvement                  -0.006875        0.003191            0.012514
# JobLevel                         0.044859        0.418382            0.297038
# JobRole                          0.019427       -0.043248           -0.003287
# JobSatisfaction                 -0.024311        0.029345            0.021082
# MaritalStatus                    0.018141       -0.046321           -0.056760
# MonthlyIncome                    0.032167        0.380543            0.260340
# MonthlyRate                      0.002295       -0.033970           -0.008861
# NumCompaniesWorked               0.000979       -0.141535           -0.115930
# OverTime                        -0.032425       -0.019568           -0.021968
# PercentSalaryHike               -0.011006       -0.030377           -0.011269
# PerformanceRating                0.003659        0.008069            0.021699
# RelationshipSatisfaction         0.023191       -0.014690           -0.030128
# StockOptionLevel                 0.003430        0.033043            0.060600
# TotalWorkingYears                0.011362        0.490539            0.367255
# TrainingTimesLastYear            0.032070        0.001604            0.002912
# WorkLifeBalance                  1.000000        0.022394            0.038592
# YearsAtCompany                   0.022394        1.000000            0.793691
# YearsInCurrentRole               0.038592        0.793691            1.000000
# YearsSinceLastPromotion          0.012377        0.522540            0.495178
# YearsWithCurrManager             0.003233        0.820255            0.732353
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.103632              0.121747
# Attrition                               -0.029263             -0.162297
# BusinessTravel                          -0.027283             -0.044321
# DailyRate                               -0.043870             -0.011516
# Department                               0.048931              0.034216
# DistanceFromHome                         0.006635             -0.000221
# Education                                0.042517              0.031210
# EducationField                           0.034094              0.013437
# EnvironmentSatisfaction                  0.027943              0.001606
# Gender                                  -0.028162             -0.036280
# HourlyRate                              -0.050165             -0.018562
# JobInvolvement                          -0.014229              0.029998
# JobLevel                                 0.216612              0.302023
# JobRole                                 -0.002902             -0.017225
# JobSatisfaction                          0.019533              0.002675
# MaritalStatus                           -0.013044             -0.043572
# MonthlyIncome                            0.196282              0.259423
# MonthlyRate                             -0.010779             -0.033466
# NumCompaniesWorked                      -0.064930             -0.128915
# OverTime                                -0.004751             -0.031931
# PercentSalaryHike                       -0.034832             -0.011293
# PerformanceRating                        0.006845              0.019275
# RelationshipSatisfaction                -0.011251             -0.014141
# StockOptionLevel                         0.022084              0.048192
# TotalWorkingYears                        0.249712              0.378519
# TrainingTimesLastYear                    0.021902              0.001316
# WorkLifeBalance                          0.012377              0.003233
# YearsAtCompany                           0.522540              0.820255
# YearsInCurrentRole                       0.495178              0.732353
# YearsSinceLastPromotion                  1.000000              0.482014
# YearsWithCurrManager                     0.482014              1.000000

# %%
upper_triangle = np.triu(df.corr())
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f',
            annot_kws={'size':10}, cmap="gist_stern", mask=upper_triangle)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (18,6))
df1.corr()['Attrition'].drop(['Attrition']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Attrition',fontsize=15)
plt.title('Correlation of features with Target Variable Attrition',fontsize = 18)
plt.show()

# %% [markdown]
# ### Balancing using SMOTE
# <b> As data is Imbalanced in nature we will need to balance target variable.</b>

# %%
from imblearn.over_sampling import SMOTE

# %%
# Oversampleing using SMOTE Techniques
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# Attrition
# 1    1158
# 0    1158
# Name: count, dtype: int64

# %% [markdown]
# ### Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
pca_new = PCA(n_components=21)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(21))

# %% [markdown]
# ### Machine Learning Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=42, test_size=.33)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (1551, 21)
# Training target vector size: (1551,)
# Test feature matrix size: (765, 21)
# Test target vector size: (765,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=242, test_size=.33)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.8640522875816994
#
#
# Confusion matrix of Logistics Regression :
#  [[322  46]
#  [ 58 339]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       368
#            1       0.88      0.85      0.87       397
#
#     accuracy                           0.86       765
#    macro avg       0.86      0.86      0.86       765
# weighted avg       0.86      0.86      0.86       765

# %% [markdown]
# ### Finding Optimal value of n_neighbors for KNN

# %%
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(30):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.33916467937944555
# RMSE value for k=  2 is: 0.293725228409004
# RMSE value for k=  3 is: 0.3352883843105734
# RMSE value for k=  4 is: 0.30249507099101003
# RMSE value for k=  5 is: 0.35791699479543954
# RMSE value for k=  6 is: 0.3505364702758674
# RMSE value for k=  7 is: 0.38262936212236764
# RMSE value for k=  8 is: 0.3687108791699814
# RMSE value for k=  9 is: 0.3927446575232716
# RMSE value for k=  10 is: 0.3791976393296807
# RMSE value for k=  11 is: 0.39770583933420295
# RMSE value for k=  12 is: 0.3860305788964616
# RMSE value for k=  13 is: 0.39107694443752145
# RMSE value for k=  14 is: 0.3809173653375313
# RMSE value for k=  15 is: 0.4009791936316524
# RMSE value for k=  16 is: 0.3927446575232716
# RMSE value for k=  17 is: 0.4090479940519309
# RMSE value for k=  18 is: 0.40422604172722165
# RMSE value for k=  19 is: 0.41852526649272975
# RMSE value for k=  20 is: 0.4058397249567139
# RMSE value for k=  21 is: 0.41852526649272975
# RMSE value for k=  22 is: 0.3960590171906697
# RMSE value for k=  23 is: 0.4169606805807075
# RMSE value for k=  24 is: 0.4009791936316524
# RMSE value for k=  25 is: 0.4106427291215469
# RMSE value for k=  26 is: 0.39440531887330776
# RMSE value for k=  27 is: 0.40422604172722165
# RMSE value for k=  28 is: 0.3927446575232716
# RMSE value for k=  29 is: 0.40744701728620475
# RMSE value for k=  30 is: 0.4009791936316524

# %%
#plotting the rmse values against k values -
plt.figure(figsize = (8,6))
plt.plot(range(30), rmse_val, color='blue', linestyle='dashed', marker='o', markerfacecolor='green', markersize=10)

# %% [markdown]
# ### Applying other classification algorithm

# %%
model=[
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 2),
        RandomForestClassifier(),
        AdaBoostClassifier(),
        GradientBoostingClassifier(),
        BaggingClassifier()]

for m in model:
    m.fit(X_train,Y_train)
    y_pred=m.predict(X_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(Y_test, y_pred))
    print('\n')
    print('============================================================================================================')
# Out:
# Classification ML Algorithm Evaluation Matrix SVC() is
#
#
# Accuracy Score :
#  0.8993464052287582
#
#
# Confusion matrix :
#  [[341  27]
#  [ 50 347]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       368
#            1       0.93      0.87      0.90       397
#
#     accuracy                           0.90       765
#    macro avg       0.90      0.90      0.90       765
# weighted avg       0.90      0.90      0.90       765
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix GaussianNB() is
#
#
# Accuracy Score :
#  0.8522875816993464
#
#
# Confusion matrix :
#  [[315  53]
#  [ 60 337]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       368
#            1       0.86      0.85      0.86       397
#
#     accuracy                           0.85       765
#    macro avg       0.85      0.85      0.85       765
# weighted avg       0.85      0.85      0.85       765
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix DecisionTreeClassifier() is
#
#
# Accuracy Score :
#  0.792156862745098
#
#
# Confusion matrix :
#  [[274  94]
#  [ 65 332]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.81      0.74      0.78       368
#            1       0.78      0.84      0.81       397
#
#     accuracy                           0.79       765
#    macro avg       0.79      0.79      0.79       765
# weighted avg       0.79      0.79      0.79       765
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix KNeighborsClassifier(n_neighbors=2) is
#
#
# Accuracy Score :
#  0.9137254901960784
#
#
# Confusion matrix :
#  [[324  44]
#  [ 22 375]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91       368
#            1       0.89      0.94      0.92       397
#
#     accuracy                           0.91       765
#    macro avg       0.92      0.91      0.91       765
# weighted avg       0.91      0.91      0.91       765
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix RandomForestClassifier() is
#
#
# Accuracy Score :
#  0.8849673202614379
#
#
# Confusion matrix :
#  [[334  34]
#  [ 54 343]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88       368
#            1       0.91      0.86      0.89       397
#
#     accuracy                           0.88       765
#    macro avg       0.89      0.89      0.88       765
# weighted avg       0.89      0.88      0.89       765
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix AdaBoostClassifier() is
#
#
# Accuracy Score :
#  0.8379084967320262
#
#
# Confusion matrix :
#  [[306  62]
#  [ 62 335]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       368
#            1       0.84      0.84      0.84       397
#
#     accuracy                           0.84       765
#    macro avg       0.84      0.84      0.84       765
# weighted avg       0.84      0.84      0.84       765
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix GradientBoostingClassifier() is
#
#
# Accuracy Score :
#  0.8614379084967321
#
#
# Confusion matrix :
#  [[320  48]
#  [ 58 339]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       368
#            1       0.88      0.85      0.86       397
#
#     accuracy                           0.86       765
#    macro avg       0.86      0.86      0.86       765
# weighted avg       0.86      0.86      0.86       765
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix BaggingClassifier() is
#
#
# Accuracy Score :
#  0.857516339869281
#
#
# Confusion matrix :
#  [[322  46]
#  [ 63 334]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       368
#            1       0.88      0.84      0.86       397
#
#     accuracy                           0.86       765
#    macro avg       0.86      0.86      0.86       765
# weighted avg       0.86      0.86      0.86       765
#
#
#
# ============================================================================================================

# %% [markdown]
# ## Conclusion
#
# This analysis shows that employee attrition is influenced by:
# - Compensation
# - Workload (overtime)
# - Job role
#
# ### Recommendations:
# - Improve salary structure
# - Reduce overtime burden
